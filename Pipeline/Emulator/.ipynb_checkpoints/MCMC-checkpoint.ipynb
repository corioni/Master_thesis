# %%
import numpy as np
from matplotlib import pyplot as plt
import emcee
from astropy.table import Table
import pandas as pd
import corner
from ps_generator import PowerSpectrumBooster
# %matplotlib inline

# %% [markdown]
# $$C(k_i, k_j) = (\frac 2  N_k) *( P(k_i) + \frac 1N )^2 * \delta_{ij}$$
#
# where $N_k = k_i^2 \Delta k \frac V { (2 \pi^2)}$ and V is the survey volume. 1/N is the so called shot-noise term and to start with I think you can just ignore it for simplicity.
# This way you would only have to specify the survey volume and the bins [kmin, ..., kmax] (e.g. log-spaced between 1e-3 h/Mpc and 1.0 h/Mpc) to be able to get the a (diagnal) covariance matrix you can use to fit against
#
# [https://arxiv.org/abs/1509.00064]

# %%
kmax = 1
kmin = 0.04
N_k = 50
k = np.geomspace(kmin,kmax, N_k)
delta_k = np.log(kmax/kmin)/N_k

from ps_generator import PowerSpectrumBooster

def P(k,params):
    emulator_folder = './emulators_tuning_8/lightning_logs'
    pofkboostfunction_version = 1
    # Unpack parameters array
    As, Omm,  mu0 = params
#    As, ns, Omb, Omm, h, mnu, w, wa, mu0 = params
    # Create a dictionary for cosmological parameters
    cosmo_par = {
        'As': As,
        'ns': 0.966,#ns,
        'Omb': 0.04,#Omb,
        'Omm': Omm,
        'h': 0.68,#h,
        'mnu': 0.15,
        'w': -1.0,
        'wa': 0.0,
    }    
    redshifts = [0.]
    booster = PowerSpectrumBooster(emulator_folder, pofkboostfunction_version)
    k, boosted_plin, boosted_pnl, boost_emulator = booster.boosted_power_spectrum(cosmo_par,mu0, redshifts,k)
    return boosted_pnl


def N(k):
    V =  256 **3
    N_k = k**3 * delta_k * V /(2* np.pi**2)  
    return N_k

def C(ki,kj,params):
    return (2/N(ki))*(P(ki,params))**2

# %%
cosmo_par = [ 2.1e-09, 0.3, 0.0]

yerr =  np.sqrt(C(k,k,cosmo_par))
Pnl = P(k,cosmo_par)
# Generate observed Pnl with errors added
Pnl_obs = Pnl + np.random.normal(0, yerr)
plt.loglog(k,Pnl,lw=0.8,label = "Emulator",alpha = 0.9)
plt.loglog(k,Pnl_obs,lw=0.8,label = "Mock",alpha = 0.9)
plt.errorbar(k,Pnl,yerr =  yerr,lw=0.8)
#plt.loglog(k,Pnl/B ,label = "non linear GR")
plt.ylim(50,3e4)
plt.legend()

# %%
def loglikelihood(params, observed_P, k):
    # Assuming P(k, params) is the model prediction function for power spectrum
    # and 'observed_P' is the numpy array containing the observed power spectrum data.
    model_P = P(k, params)  # Now P(k, params) is clearly a function call
    variance = C(k, k, params)  # This function or value should return the variance at each k

    # Make sure variance is not zero to avoid division by zero
    if np.any(variance <= 0):
        return -np.inf

    diff = observed_P - model_P
    log_p = -0.5 * ((diff ** 2) / variance + np.log(2 * np.pi * variance))
    return np.sum(log_p)

def logprior(params):
#    As, ns, Omb, Omm, h, mnu, w, wa, mu0 = params
    As,  Omm,  mu0 = params   
    # Define the intervals for each parameter
    intervals = {
        'mu0':  [-0.1, 0.1],
        'Omm':  [0.24, 0.4],
        'h':    [0.61, 0.73],
        'A_s':  [1.7e-9, 2.5e-9],
        'w':    [-1.3, -0.7],
        'wa':   [-0.7, 0.5],
        'mnu':  [0.0, 0.15],
        'Omb':  [0.04, 0.06],
        'ns':   [0.92, 1.00],
    }

    # Check each parameter against its interval
    if (
        intervals['mu0'][0] <= mu0 <= intervals['mu0'][1] and
        intervals['Omm'][0] <= Omm <= intervals['Omm'][1] and
        #intervals['h'][0] <= h <= intervals['h'][1] and
        intervals['A_s'][0] <= As <= intervals['A_s'][1] 
        #intervals['w'][0] <= w <= intervals['w'][1] and
        #intervals['wa'][0] <= wa <= intervals['wa'][1] and
        #intervals['mnu'][0] <= mnu <= intervals['mnu'][1] and
        #intervals['Omb'][0] <= Omb <= intervals['Omb'][1] and
        #intervals['ns'][0] <= ns <= intervals['ns'][1]
    ):
        return 0
    else:
        return -np.inf

def logposterior(params, P,k):
    lp = logprior(params)
    if not np.isinf(lp):
        return lp+loglikelihood(params, P,k)
    else:
        return lp

# %%
ndim = 3

nwalkers = 32


# Define the intervals for each parameter in the specified order
intervals = {
    'As':  [1.7e-9, 2.5e-9],
    #'ns':  [0.92, 1.00],
    #'Omb': [0.04, 0.06],
    'Omm': [0.24, 0.4],
    #'h':   [0.61, 0.73],
    #'mnu': [0.0, 0.15],
    #'w':   [-1.3, -0.7],
    #'wa':  [-0.7, 0.5],
    'mu0': [-0.1, 0.1],
}

# Function to generate a random parameter set
def generate_random_parameters(intervals):
    # Sort the keys according to the specified order and then generate random parameters
    sorted_keys = ['As', 'Omm', 'mu0']    
    #sorted_keys = ['As', 'ns', 'Omb', 'Omm', 'h', 'mnu', 'w', 'wa', 'mu0']
    return [np.random.uniform(*intervals[key]) for key in sorted_keys]

# Generate parameters 20 times
pos = np.array([generate_random_parameters(intervals) for _ in range(nwalkers)])

# Print the shape of the generated pos matrix
print("Shape of pos:", pos.shape)  
assert pos.shape == (nwalkers, len(intervals)), "Shape mismatch"
# Out:
# Shape of pos: (32, 3)

# %%
import emcee
import multiprocessing
from multiprocessing import Pool

# Assuming you have already functions like 'logposterior' defined as 
# the posterior probability function, along with other necessary variables.

run_mcmc = False
if run_mcmc:
    # Initializing the sampler with the number of walkers, dimensions, and log-posterior
    sampler = emcee.EnsembleSampler(nwalkers, ndim, logposterior, args=(Pnl_obs, k))

    # The 'state' variable now contains the state of the chain after the last sample

    sampler = emcee.EnsembleSampler(nwalkers,ndim,logposterior,args=(Pnl_obs,k));
    state = sampler.run_mcmc(pos,50,progress = True)
    sampler.reset()
    state = sampler.run_mcmc(state,250,progress = True)
    import pickle


    # Saving the sampler to a file using pickle
    with open('sampler_250.pkl', 'wb') as f:
        pickle.dump(sampler, f)

# %%
import pickle
# Load the sampler from the file
with open('sampler_5000.pkl', 'rb') as f:
    loaded_sampler = pickle.load(f)

sample_more =False
if sample_more:
    state = loaded_sampler.run_mcmc(state,750,progress = True)
    # Saving the sampler to a file using pickle
    with open('sampler_1000.pkl', 'wb') as f:
        pickle.dump(loaded_sampler, f)

# %%
import corner
import matplotlib.pyplot as plt

corner_figure = corner.corner(
    loaded_sampler.flatchain,
    quantiles=[0.16, 0.5, 0.84],
    #range=[(1.6e-9, 2.4e-9),(0.92, 1.00),(0.04, 0.07),(0.24, 0.45),(0.61, 0.73),(-0.1, 0.1)],
    #labels=[r'$A_s$', r'$n_s$', r'$\Omega_b$', r'$\Omega_{cdm}$', r'$h$', r'$\mu_0$'],
    labels=[r'$A_s$', r'$\Omega_{cdm}$', r'$\mu_0$'],
    show_titles=True,
    title_fmt='.2e',
    title_kwargs={"fontsize": 10},
    smooth1d =1.,
    smooth = 1.5,
    # You can change the color of the histogram fill with the 'hist_kwargs' argument
    hist_kwargs={"color": "c", "linewidth": 1.5, "alpha": 0.9},#,"fill":True},
    # Or change the appearance of the density plots
    plot_density=False,#True,  # To disable density plot
    plot_datapoints=False,  # To plot the individual data points
    hist_bin_factor =1.5,
    max_n_ticks=5,
    data_kwargs={"marker": '.', "alpha": 0.2, "color": 'darkblue'},
    fill_contours=True,  # To fill the contour plots instead of just lines
    contourf_kwargs={"colors": None, "alpha": 0.5}  # Adjust contour colors and transparency
)

# The expected values
expected_values = {
    r'$A_s$': 2.1e-9,
    r'$\Omega_{cdm}$': 0.3,
    r'$\mu_0$': 0.0
}

# Extract the axes from the corner plot to add lines
axes = np.array(corner_figure.axes).reshape((3, 3))

# Loop over the axes to add lines at the expected values
for i, param in enumerate([r'$A_s$', r'$\Omega_{cdm}$', r'$\mu_0$']):
    # Add vertical lines on each column
    for j in range(i + 1):
        ax = axes[i, j]
        ax.axvline(expected_values[param], color='r', linestyle='--') # For column parameters
    
    # Add horizontal lines on each row
    #for j in range(i):
    #    ax = axes[i,j]
    #    ax.axhline(expected_values[param], color='r', linestyle='--') # For row parameters

    # Add a legend or label if necessary
    #axes[i, i].legend([param], loc='upper right')

# You might want to adjust the size of the figure
#corner_figure.set_size_inches(10, 10)

# Show or save the plot
plt.show()
# or
plt.savefig('corner_plot.pdf')
